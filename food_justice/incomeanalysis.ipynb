# %%
import pandas as pd

# %%
df = pd.read_csv('medianincomedata.csv')
df
# Out:
#                    GEO_ID                                     NAME  \
# 0               Geography                     Geographic Area Name
# 1    1400000US48113000100     Census Tract 1; Dallas County; Texas
# 2    1400000US48113000201  Census Tract 2.01; Dallas County; Texas
# 3    1400000US48113000202  Census Tract 2.02; Dallas County; Texas
# 4    1400000US48113000300     Census Tract 3; Dallas County; Texas
# ..                    ...                                      ...
# 641  1400000US48113021100   Census Tract 211; Dallas County; Texas
# 642  1400000US48113021200   Census Tract 212; Dallas County; Texas
# 643  1400000US48113980000  Census Tract 9800; Dallas County; Texas
# 644  1400000US48113980100  Census Tract 9801; Dallas County; Texas
# 645  1400000US48113980200  Census Tract 9802; Dallas County; Texas
#
#                                         S1903_C01_001E  \
# 0    Estimate!!Number!!HOUSEHOLD INCOME BY RACE AND...
# ...

# %%
df1 = df.copy()
df1 = df1.rename(columns={"GEO_ID":"geography",
                          "NAME":"name",
                          "S1903_C01_015E": "family_estimate",
                          "S1903_C01_034E": "nonfamily_estimate"})

df1
# Out:
#                 geography                                     name  \
# 0               Geography                     Geographic Area Name
# 1    1400000US48113000100     Census Tract 1; Dallas County; Texas
# 2    1400000US48113000201  Census Tract 2.01; Dallas County; Texas
# 3    1400000US48113000202  Census Tract 2.02; Dallas County; Texas
# 4    1400000US48113000300     Census Tract 3; Dallas County; Texas
# ..                    ...                                      ...
# 641  1400000US48113021100   Census Tract 211; Dallas County; Texas
# 642  1400000US48113021200   Census Tract 212; Dallas County; Texas
# 643  1400000US48113980000  Census Tract 9800; Dallas County; Texas
# 644  1400000US48113980100  Census Tract 9801; Dallas County; Texas
# 645  1400000US48113980200  Census Tract 9802; Dallas County; Texas
#
#                                         S1903_C01_001E  \
# 0    Estimate!!Number!!HOUSEHOLD INCOME BY RACE AND...
# ...

# %%
print(df1)
# Out:
#                 geography                                     name  \
# 0               Geography                     Geographic Area Name
# 1    1400000US48113000100     Census Tract 1; Dallas County; Texas
# 2    1400000US48113000201  Census Tract 2.01; Dallas County; Texas
# 3    1400000US48113000202  Census Tract 2.02; Dallas County; Texas
# 4    1400000US48113000300     Census Tract 3; Dallas County; Texas
# ..                    ...                                      ...
# 641  1400000US48113021100   Census Tract 211; Dallas County; Texas
# 642  1400000US48113021200   Census Tract 212; Dallas County; Texas
# 643  1400000US48113980000  Census Tract 9800; Dallas County; Texas
# 644  1400000US48113980100  Census Tract 9801; Dallas County; Texas
# 645  1400000US48113980200  Census Tract 9802; Dallas County; Texas
#
#                                         S1903_C01_001E  \
# 0    Estimate!!Number!!HOUSEHOLD INCOME BY RACE AND...
# ...

# %%
df1_subset = df1[[
    "geography",
    "name",
    "family_estimate",
    "nonfamily_estimate"
]]

# %%
print(df1.columns.tolist())
# Out:
# ['geography', 'name', 'S1903_C01_001E', 'S1903_C01_001M', 'S1903_C01_002E', 'S1903_C01_002M', 'S1903_C01_003E', 'S1903_C01_003M', 'S1903_C01_004E', 'S1903_C01_004M', 'S1903_C01_005E', 'S1903_C01_005M', 'S1903_C01_006E', 'S1903_C01_006M', 'S1903_C01_007E', 'S1903_C01_007M', 'S1903_C01_008E', 'S1903_C01_008M', 'S1903_C01_009E', 'S1903_C01_009M', 'S1903_C01_010E', 'S1903_C01_010M', 'S1903_C01_011E', 'S1903_C01_011M', 'S1903_C01_012E', 'S1903_C01_012M', 'S1903_C01_013E', 'S1903_C01_013M', 'S1903_C01_014E', 'S1903_C01_014M', 'family_estimate', 'S1903_C01_015M', 'S1903_C01_016E', 'S1903_C01_016M', 'S1903_C01_017E', 'S1903_C01_017M', 'S1903_C01_018E', 'S1903_C01_018M', 'S1903_C01_019E', 'S1903_C01_019M', 'S1903_C01_020E', 'S1903_C01_020M', 'S1903_C01_021E', 'S1903_C01_021M', 'S1903_C01_022E', 'S1903_C01_022M', 'S1903_C01_023E', 'S1903_C01_023M', 'S1903_C01_024E', 'S1903_C01_024M', 'S1903_C01_025E', 'S1903_C01_025M', 'S1903_C01_026E', 'S1903_C01_026M', 'S1903_C01_027E', 'S1903_C01_027M', 'S1
# ...

# %%
df1_subset
# Out:
#                 geography                                     name  \
# 0               Geography                     Geographic Area Name
# 1    1400000US48113000100     Census Tract 1; Dallas County; Texas
# 2    1400000US48113000201  Census Tract 2.01; Dallas County; Texas
# 3    1400000US48113000202  Census Tract 2.02; Dallas County; Texas
# 4    1400000US48113000300     Census Tract 3; Dallas County; Texas
# ..                    ...                                      ...
# 641  1400000US48113021100   Census Tract 211; Dallas County; Texas
# 642  1400000US48113021200   Census Tract 212; Dallas County; Texas
# 643  1400000US48113980000  Census Tract 9800; Dallas County; Texas
# 644  1400000US48113980100  Census Tract 9801; Dallas County; Texas
# 645  1400000US48113980200  Census Tract 9802; Dallas County; Texas
#
#                           family_estimate  \
# 0    Estimate!!Number!!FAMILIES!!Families
# 1                                    1064
# ...

# %%
#delete row
df1_subset = df1_subset.drop(0)
df1_subset
# Out:
#                 geography                                     name  \
# 1    1400000US48113000100     Census Tract 1; Dallas County; Texas
# 2    1400000US48113000201  Census Tract 2.01; Dallas County; Texas
# 3    1400000US48113000202  Census Tract 2.02; Dallas County; Texas
# 4    1400000US48113000300     Census Tract 3; Dallas County; Texas
# 5    1400000US48113000401  Census Tract 4.01; Dallas County; Texas
# ..                    ...                                      ...
# 641  1400000US48113021100   Census Tract 211; Dallas County; Texas
# 642  1400000US48113021200   Census Tract 212; Dallas County; Texas
# 643  1400000US48113980000  Census Tract 9800; Dallas County; Texas
# 644  1400000US48113980100  Census Tract 9801; Dallas County; Texas
# 645  1400000US48113980200  Census Tract 9802; Dallas County; Texas
#
#     family_estimate nonfamily_estimate
# 1              1064                665
# 2               751                462
# 3               967                713
# ...

# %%
df_family = df1_subset
df_family
# Out:
#                 geography                                     name  \
# 1    1400000US48113000100     Census Tract 1; Dallas County; Texas
# 2    1400000US48113000201  Census Tract 2.01; Dallas County; Texas
# 3    1400000US48113000202  Census Tract 2.02; Dallas County; Texas
# 4    1400000US48113000300     Census Tract 3; Dallas County; Texas
# 5    1400000US48113000401  Census Tract 4.01; Dallas County; Texas
# ..                    ...                                      ...
# 641  1400000US48113021100   Census Tract 211; Dallas County; Texas
# 642  1400000US48113021200   Census Tract 212; Dallas County; Texas
# 643  1400000US48113980000  Census Tract 9800; Dallas County; Texas
# 644  1400000US48113980100  Census Tract 9801; Dallas County; Texas
# 645  1400000US48113980200  Census Tract 9802; Dallas County; Texas
#
#     family_estimate nonfamily_estimate
# 1              1064                665
# 2               751                462
# 3               967                713
# ...

# %% [markdown]
# # Mapping

# %%
import shapely
import numpy as np
import fiona
#%pip install --upgrade geopandas shapely
#%pip install --upgrade geopandas fiona

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %matplotlib inline
# %config InlineBackend.figure_format = "retina"
#counties = gpd.read_file("tl_2024_48_tract", engine="fiona")

# %%
gdf = gpd.read_file("tl_2024_48_tract.shp")
# Out:
# ---------------------------------------------------------------------------
# DataSourceError                           Traceback (most recent call last)
# Cell In[122], line 1
# ----> 1 gdf = gpd.read_file("tl_2024_48_tract.shp")
#
# File c:\Users\saraz\Downloads\Desktop\Lib\site-packages\geopandas\io\file.py:316, in _read_file(filename, bbox, mask, columns, rows, engine, **kwargs)
#     313             filename = response.read()
#     315 if engine == "pyogrio":
# --> 316     return _read_file_pyogrio(
#     317         filename, bbox=bbox, mask=mask, columns=columns, rows=rows, **kwargs
#     318     )
#     320 elif engine == "fiona":
#     321     if pd.api.types.is_file_like(filename):
#
# File c:\Users\saraz\Downloads\Desktop\Lib\site-packages\geopandas\io\file.py:576, in _read_file_pyogrio(path_or_bytes, bbox, mask, rows, **kwargs)
#     567     warnings.warn(
#     568         "The 'include_fields' and 'ignore_fields' keywords are deprecated, and "
# ...

# %%
import os
os.listdir()
# Out:
# ['acsanalysis.ipynb',
#  'ACSST5Y2024.S0701-Data.csv',
#  'ACSST5Y2024.S0701-Table-Notes.txt',
#  'ACSST5Y2024.S1903-Table-Notes.txt',
#  'ACSST5Y2024.S2201-Data.csv',
#  'ACSST5Y2024.S2201-Table-Notes.txt',
#  'acs_income.csv',
#  'incomeanalysis.ipynb',
#  'incomedata.csv',
#  'income_data.csv',
#  'Mapping Food Justice.pdf',
#  'medianincomedata.csv',
#  'medianincometablenotes.txt',
#  'mobilitydata.csv',
#  'mobilitytablenotes.txt',
#  'SNAPdata.csv',
#  'SNAPtablenotes.txt',
#  'snap_data.csv',
#  'tl_2024_48_tract',
#  'tl_2024_48_tract.shp',
#  'tl_2024_48_tract.zip',
#  'Untitled-1.ipynb']

# %%
gdf = gpd.read_file("tl_2024_48_tract.zip")
gdf.head()
# Out:
#   STATEFP COUNTYFP TRACTCE        GEOID               GEOIDFQ    NAME  \
# 0      48      157  674100  48157674100  1400000US48157674100    6741
# 1      48      157  674200  48157674200  1400000US48157674200    6742
# 2      48      441  013501  48441013501  1400000US48441013501  135.01
# 3      48      441  013602  48441013602  1400000US48441013602  136.02
# 4      48      441  013601  48441013601  1400000US48441013601  136.01
#
#               NAMELSAD  MTFCC FUNCSTAT      ALAND   AWATER     INTPTLAT  \
# 0    Census Tract 6741  G5020        S    4170615        0  +29.5791692
# 1    Census Tract 6742  G5020        S    5800266   189859  +29.5713421
# 2  Census Tract 135.01  G5020        S  866463520  4539887  +32.1806265
# 3  Census Tract 136.02  G5020        S  665184779   422010  +32.3991003
# 4  Census Tract 136.01  G5020        S   36492558        0  +32.4639334
#
#        INTPTLON                                           geometry
# ...

# %%
import zipfile

with zipfile.ZipFile("tl_2024_48_tract.zip", "r") as zip_ref:
    zip_ref.extractall("tl_2024_48_tract")

# %%
gdf = gpd.read_file("tl_2024_48_tract/tl_2024_48_tract.shp")
gdf.head()
# Out:
#   STATEFP COUNTYFP TRACTCE        GEOID               GEOIDFQ    NAME  \
# 0      48      157  674100  48157674100  1400000US48157674100    6741
# 1      48      157  674200  48157674200  1400000US48157674200    6742
# 2      48      441  013501  48441013501  1400000US48441013501  135.01
# 3      48      441  013602  48441013602  1400000US48441013602  136.02
# 4      48      441  013601  48441013601  1400000US48441013601  136.01
#
#               NAMELSAD  MTFCC FUNCSTAT      ALAND   AWATER     INTPTLAT  \
# 0    Census Tract 6741  G5020        S    4170615        0  +29.5791692
# 1    Census Tract 6742  G5020        S    5800266   189859  +29.5713421
# 2  Census Tract 135.01  G5020        S  866463520  4539887  +32.1806265
# 3  Census Tract 136.02  G5020        S  665184779   422010  +32.3991003
# 4  Census Tract 136.01  G5020        S   36492558        0  +32.4639334
#
#        INTPTLON                                           geometry
# ...

# %%
dallas = gdf[gdf["COUNTYFP"] == "113"]

# %%
dallas
# Out:
#      STATEFP COUNTYFP TRACTCE        GEOID               GEOIDFQ    NAME  \
# 233       48      113  016638  48113016638  1400000US48113016638  166.38
# 321       48      113  013630  48113013630  1400000US48113013630  136.30
# 898       48      113  012211  48113012211  1400000US48113012211  122.11
# 899       48      113  012400  48113012400  1400000US48113012400     124
# 900       48      113  016513  48113016513  1400000US48113016513  165.13
# ...      ...      ...     ...          ...                   ...     ...
# 6830      48      113  016302  48113016302  1400000US48113016302  163.02
# 6844      48      113  016511  48113016511  1400000US48113016511  165.11
# 6851      48      113  016615  48113016615  1400000US48113016615  166.15
# 6852      48      113  016616  48113016616  1400000US48113016616  166.16
# 6853      48      113  018111  48113018111  1400000US48113018111  181.11
#
#                  NAMELSAD  MTFCC FUNCSTAT     ALAND  AWATER     INTPTLAT  \
# ...

# %%
merged = dallas.merge(
    df,
    left_on="GEOIDFQ",
    right_on="GEO_ID",
    how="left"
)

# %%
merged
# Out:
#     STATEFP COUNTYFP TRACTCE        GEOID               GEOIDFQ  NAME_x  \
# 0        48      113  016638  48113016638  1400000US48113016638  166.38
# 1        48      113  013630  48113013630  1400000US48113013630  136.30
# 2        48      113  012211  48113012211  1400000US48113012211  122.11
# 3        48      113  012400  48113012400  1400000US48113012400     124
# 4        48      113  016513  48113016513  1400000US48113016513  165.13
# ..      ...      ...     ...          ...                   ...     ...
# 640      48      113  016302  48113016302  1400000US48113016302  163.02
# 641      48      113  016511  48113016511  1400000US48113016511  165.11
# 642      48      113  016615  48113016615  1400000US48113016615  166.15
# 643      48      113  016616  48113016616  1400000US48113016616  166.16
# 644      48      113  018111  48113018111  1400000US48113018111  181.11
#
#                 NAMELSAD  MTFCC FUNCSTAT     ALAND  ...  S1903_C03_036E  \
# ...

# %%
df_subset = df[[
    "GEO_ID",
    "S1903_C01_015E",
    "S1903_C01_034E"
]]

# %%
df_subset
# Out:
#                    GEO_ID                        S1903_C01_015E  \
# 0               Geography  Estimate!!Number!!FAMILIES!!Families
# 1    1400000US48113000100                                  1064
# 2    1400000US48113000201                                   751
# 3    1400000US48113000202                                   967
# 4    1400000US48113000300                                  1086
# ..                    ...                                   ...
# 641  1400000US48113021100                                   841
# 642  1400000US48113021200                                  1387
# 643  1400000US48113980000                                     0
# 644  1400000US48113980100                                     0
# 645  1400000US48113980200                                    74
#
#                                         S1903_C01_034E
# 0    Estimate!!Number!!NONFAMILY HOUSEHOLDS!!Nonfam...
# 1                                                  665
# ...

# %%
merged["S1903_C01_015E"] = pd.to_numeric(
    merged["S1903_C01_015E"],
    errors="coerce"
)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10, 10))

merged.plot(
    column="S1903_C01_015E",
    cmap="viridis",
    legend=True,
    ax=ax
)

plt.title("Family Income by Census Tract in Dallas County")
plt.axis("off")
plt.show()

# %%
df_subset_2 = df[[
    "GEO_ID",
    "S1903_C03_001E"

]]
df_subset_2
# Out:
#                    GEO_ID                                     S1903_C03_001E
# 0               Geography  Estimate!!Median income (dollars)!!HOUSEHOLD I...
# 1    1400000US48113000100                                             198865
# 2    1400000US48113000201                                             197614
# 3    1400000US48113000202                                             154259
# 4    1400000US48113000300                                             129485
# ..                    ...                                                ...
# 641  1400000US48113021100                                              37717
# 642  1400000US48113021200                                              70100
# 643  1400000US48113980000                                                  -
# 644  1400000US48113980100                                                  -
# 645  1400000US48113980200                                                  -
#
# [646 rows x 2 columns]

# %%
#make sure numeric 
merged["S1903_C03_001E"] = pd.to_numeric(
    merged["S1903_C03_001E"],
    errors="coerce"
)

# %%
fig, ax = plt.subplots(figsize=(10, 10))

merged.plot(
    column="S1903_C03_001E",
    cmap="viridis",
    legend=True,
    ax=ax
)

plt.title("Median Household Income by Census Tract in Dallas County")
plt.axis("off")
plt.show()
