# %% [markdown]
# # 1. Median Income Data

# %%
import pandas as pd
import shapely
import numpy as np
import fiona
#%pip install --upgrade geopandas shapely
#%pip install --upgrade geopandas fiona
import geopandas as gpd
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = "retina"
import os
os.listdir()
# Out:
# ['ACSST5Y2024.S0802-Data.csv',
#  'ACSST5Y2024.S1903-Data.csv',
#  'ACSST5Y2024.S2201-Data.csv',
#  'collin_county_heat_maps.ipynb',
#  'collin_county_snap_data.csv',
#  'collin_income_data.csv',
#  'collin_vehicle_data.csv',
#  'income_data.csv',
#  'tl_2024_48_tract.cpg',
#  'tl_2024_48_tract.dbf',
#  'tl_2024_48_tract.prj',
#  'tl_2024_48_tract.shp',
#  'tl_2024_48_tract.shp.ea.iso.xml',
#  'tl_2024_48_tract.shp.iso.xml',
#  'tl_2024_48_tract.shx']

# %%
df = pd.read_csv('collin_income_data.csv')
df
# Out:
#                    GEO_ID                                       NAME  \
# 0               Geography                       Geographic Area Name
# 1    1400000US48085030101  Census Tract 301.01; Collin County; Texas
# 2    1400000US48085030102  Census Tract 301.02; Collin County; Texas
# 3    1400000US48085030201  Census Tract 302.01; Collin County; Texas
# 4    1400000US48085030202  Census Tract 302.02; Collin County; Texas
# ..                    ...                                        ...
# 216  1400000US48085032015  Census Tract 320.15; Collin County; Texas
# 217  1400000US48085032016  Census Tract 320.16; Collin County; Texas
# 218  1400000US48085032017  Census Tract 320.17; Collin County; Texas
# 219  1400000US48085032018  Census Tract 320.18; Collin County; Texas
# 220  1400000US48085032019  Census Tract 320.19; Collin County; Texas
#
#                                         S1903_C01_001E  \
# 0    Estimate!!Number!!HOUSEHOLD INCOME BY RACE AND...
# 1                                                 1012
# 2                                                 1323
# 3                                                 2666
# 4                                                 3468
# ..                                                 ...
# 216                                                863
# 217                                                760
# 218                                               2281
# 219                                               1485
# 220                                                928
#
#                                         S1903_C01_001M  \
# 0    Margin of Error!!Number!!HOUSEHOLD INCOME BY R...
# 1                                                  117
# 2                                                  151
# 3                                                  263
# 4                                                  254
# ..                                                 ...
# 216                                                118
# 217                                                 81
# 218                                                316
# 219                                                151
# 220                                                134
#
#                                         S1903_C01_002E  \
# 0    Estimate!!Number!!HOUSEHOLD INCOME BY RACE AND...
# 1                                                  875
# 2                                                 1225
# 3                                                 1706
# 4                                                 2562
# ..                                                 ...
# 216                                                561
# 217                                                347
# 218                                                984
# 219                                               1012
# 220                                                485
#
#                                         S1903_C01_002M  \
# 0    Margin of Error!!Number!!HOUSEHOLD INCOME BY R...
# 1                                                  114
# 2                                                  157
# 3                                                  241
# 4                                                  300
# ..                                                 ...
# 216                                                115
# 217                                                109
# 218                                                246
# 219                                                167
# 220                                                128
#
#                                         S1903_C01_003E  \
# 0    Estimate!!Number!!HOUSEHOLD INCOME BY RACE AND...
# 1                                                    6
# 2                                                    4
# 3                                                  336
# 4                                                  150
# ..                                                 ...
# 216                                                128
# 217                                                 61
# 218                                                393
# 219                                                201
# 220                                                 43
#
#                                         S1903_C01_003M  \
# 0    Margin of Error!!Number!!HOUSEHOLD INCOME BY R...
# 1                                                    8
# 2                                                    8
# 3                                                  234
# 4                                                  123
# ..                                                 ...
# 216                                                 99
# 217                                                 57
# 218                                                200
# 219                                                144
# 220                                                 36
#
#                                         S1903_C01_004E  \
# 0    Estimate!!Number!!HOUSEHOLD INCOME BY RACE AND...
# 1                                                    0
# 2                                                    3
# 3                                                    3
# 4                                                   17
# ..                                                 ...
# 216                                                 20
# 217                                                  0
# 218                                                  0
# 219                                                  0
# 220                                                  0
#
#                                         S1903_C01_004M  ...  \
# 0    Margin of Error!!Number!!HOUSEHOLD INCOME BY R...  ...
# 1                                                   15  ...
# 2                                                    8  ...
# 3                                                    5  ...
# 4                                                   25  ...
# ..                                                 ...  ...
# 216                                                 21  ...
# 217                                                 15  ...
# 218                                                 21  ...
# 219                                                 15  ...
# 220                                                 15  ...
#
#                                         S1903_C03_036E  \
# 0    Estimate!!Median income (dollars)!!NONFAMILY H...
# 1                                                41875
# 2                                                61056
# 3                                                50723
# 4                                                74250
# ..                                                 ...
# 216                                              24297
# 217                                                  -
# 218                                              72978
# 219                                              73530
# 220                                                  -
#
#                                         S1903_C03_036M  \
# 0    Margin of Error!!Median income (dollars)!!NONF...
# 1                                                36052
# 2                                                 8745
# 3                                                14946
# 4                                                63335
# ..                                                 ...
# 216                                              15902
# 217                                                 **
# 218                                              54186
# 219                                               7978
# 220                                                 **
#
#                                         S1903_C03_037E  \
# 0    Estimate!!Median income (dollars)!!NONFAMILY H...
# 1                                               162891
# 2                                               176109
# 3                                                    -
# 4                                                    -
# ..                                                 ...
# 216                                                  -
# 217                                                  -
# 218                                                  -
# 219                                                  -
# 220                                                  -
#
#                                         S1903_C03_037M  \
# 0    Margin of Error!!Median income (dollars)!!NONF...
# 1                                                91723
# 2                                                  893
# 3                                                   **
# 4                                                   **
# ..                                                 ...
# 216                                                 **
# 217                                                 **
# 218                                                 **
# 219                                                 **
# 220                                                 **
#
#                                         S1903_C03_038E  \
# 0    Estimate!!Median income (dollars)!!NONFAMILY H...
# 1                                                86023
# 2                                                66563
# 3                                                    -
# 4                                                    -
# ..                                                 ...
# 216                                              91435
# 217                                                  -
# 218                                             106549
# 219                                              81146
# 220                                                  -
#
#                                         S1903_C03_038M  \
# 0    Margin of Error!!Median income (dollars)!!NONF...
# 1                                                84779
# 2                                                44741
# 3                                                   **
# 4                                                   **
# ..                                                 ...
# 216                                              37797
# 217                                                 **
# 218                                              10908
# 219                                              54263
# 220                                                 **
#
#                                         S1903_C03_039E  \
# 0    Estimate!!Median income (dollars)!!NONFAMILY H...
# 1                                                    -
# 2                                                58646
# 3                                                 8990
# 4                                                61534
# ..                                                 ...
# 216                                              92037
# 217                                                  -
# 218                                             121542
# 219                                             100515
# 220                                                  -
#
#                                         S1903_C03_039M  \
# 0    Margin of Error!!Median income (dollars)!!NONF...
# 1                                                   **
# 2                                                56249
# 3                                                  848
# 4                                                 7376
# ..                                                 ...
# 216                                              51129
# 217                                                 **
# 218                                              36893
# 219                                              63363
# 220                                                 **
#
#                                         S1903_C03_040E  \
# 0    Estimate!!Median income (dollars)!!NONFAMILY H...
# 1                                                87045
# 2                                                    -
# 3                                                    -
# 4                                               223958
# ..                                                 ...
# 216                                                  -
# 217                                                  -
# 218                                                  -
# 219                                                  -
# 220                                                  -
#
#                                         S1903_C03_040M
# 0    Margin of Error!!Median income (dollars)!!NONF...
# 1                                                56809
# 2                                                   **
# 3                                                   **
# 4                                                16071
# ..                                                 ...
# 216                                                 **
# 217                                                 **
# 218                                                 **
# 219                                                 **
# 220                                                 **
#
# [221 rows x 242 columns]

# %%
gdf = gpd.read_file("tl_2024_48_tract.shp")
collin = gdf[gdf["COUNTYFP"] == "085"]

# %%
merged = collin.merge(
    df,
    left_on="GEOIDFQ",
    right_on="GEO_ID",
    how="left"
)

# %%
merged["S1903_C03_001E"] = pd.to_numeric(
    merged["S1903_C03_001E"],
    errors="coerce"
)

# %%
fig, ax = plt.subplots(figsize=(10, 10))

merged.plot(
    column="S1903_C03_001E",
    cmap="viridis",
    legend=True,
    ax=ax
)

plt.title("Median Household Income by Census Tract in Collin County")
plt.axis("off")
plt.show()

# %% [markdown]
# # 2. Mobility Map (No Vehicle Access)

# %%
df = pd.read_csv('collin_vehicle_data.csv')
df
# Out:
#                    GEO_ID                                       NAME  \
# 0               Geography                       Geographic Area Name
# 1    1400000US48085030101  Census Tract 301.01; Collin County; Texas
# 2    1400000US48085030102  Census Tract 301.02; Collin County; Texas
# 3    1400000US48085030201  Census Tract 302.01; Collin County; Texas
# 4    1400000US48085030202  Census Tract 302.02; Collin County; Texas
# ..                    ...                                        ...
# 216  1400000US48085032015  Census Tract 320.15; Collin County; Texas
# 217  1400000US48085032016  Census Tract 320.16; Collin County; Texas
# 218  1400000US48085032017  Census Tract 320.17; Collin County; Texas
# 219  1400000US48085032018  Census Tract 320.18; Collin County; Texas
# 220  1400000US48085032019  Census Tract 320.19; Collin County; Texas
#
#                                  S0802_C01_001E  \
# 0    Estimate!!Total!!Workers 16 years and over
# 1                                          1581
# 2                                          1954
# 3                                          3978
# 4                                          4621
# ..                                          ...
# 216                                        1151
# 217                                        1142
# 218                                        3132
# 219                                        2042
# 220                                        1398
#
#                                         S0802_C01_001M  \
# 0    Margin of Error!!Total!!Workers 16 years and over
# 1                                                  194
# 2                                                  260
# 3                                                  527
# 4                                                  494
# ..                                                 ...
# 216                                                242
# 217                                                120
# 218                                                802
# 219                                                244
# 220                                                270
#
#                                         S0802_C01_002E  \
# 0    Estimate!!Total!!Workers 16 years and over!!AG...
# 1                                                  2.5
# 2                                                  3.6
# 3                                                  5.1
# 4                                                  1.8
# ..                                                 ...
# 216                                               10.8
# 217                                                2.5
# 218                                                  0
# 219                                                7.6
# 220                                                2.4
#
#                                         S0802_C01_002M  \
# 0    Margin of Error!!Total!!Workers 16 years and o...
# 1                                                  1.7
# 2                                                  2.6
# 3                                                  3.7
# 4                                                  1.3
# ..                                                 ...
# 216                                                  6
# 217                                                2.4
# 218                                                1.6
# 219                                                  6
# 220                                                2.3
#
#                                         S0802_C01_003E  \
# 0    Estimate!!Total!!Workers 16 years and over!!AG...
# 1                                                  9.1
# 2                                                  6.7
# 3                                                  3.3
# 4                                                  3.4
# ..                                                 ...
# 216                                                9.7
# 217                                                9.5
# 218                                                3.5
# 219                                                  5
# 220                                                4.1
#
#                                         S0802_C01_003M  \
# 0    Margin of Error!!Total!!Workers 16 years and o...
# 1                                                  3.4
# 2                                                  4.6
# 3                                                  2.3
# 4                                                  1.9
# ..                                                 ...
# 216                                                4.4
# 217                                                3.9
# 218                                                4.4
# 219                                                5.2
# 220                                                2.4
#
#                                         S0802_C01_004E  \
# 0    Estimate!!Total!!Workers 16 years and over!!AG...
# 1                                                 37.4
# 2                                                 39.4
# 3                                                 44.4
# 4                                                 53.8
# ..                                                 ...
# 216                                               46.4
# 217                                               44.1
# 218                                               44.3
# 219                                               34.5
# 220                                               24.4
#
#                                         S0802_C01_004M  ...  \
# 0    Margin of Error!!Total!!Workers 16 years and o...  ...
# 1                                                  7.4  ...
# 2                                                  7.9  ...
# 3                                                  8.8  ...
# 4                                                  6.7  ...
# ..                                                 ...  ...
# 216                                                9.5  ...
# 217                                                6.1  ...
# 218                                               14.1  ...
# 219                                                9.5  ...
# 220                                                7.7  ...
#
#                                         S0802_C05_097E  \
# 0    Estimate!!Worked from home!!Workers 16 years a...
# 1                                                 49.3
# 2                                                 36.7
# 3                                                 45.2
# 4                                                 20.4
# ..                                                 ...
# 216                                                 26
# 217                                               37.1
# 218                                               44.1
# 219                                               20.8
# 220                                               28.9
#
#                                         S0802_C05_097M  \
# 0    Margin of Error!!Worked from home!!Workers 16 ...
# 1                                                 25.3
# 2                                                 19.1
# 3                                                 18.8
# 4                                                    9
# ..                                                 ...
# 216                                               21.7
# 217                                               13.9
# 218                                               36.5
# 219                                               12.6
# 220                                               16.2
#
#                                         S0802_C05_098E  \
# 0    Estimate!!Worked from home!!PERCENT ALLOCATED!...
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 216                                                (X)
# 217                                                (X)
# 218                                                (X)
# 219                                                (X)
# 220                                                (X)
#
#                                         S0802_C05_098M  \
# 0    Margin of Error!!Worked from home!!PERCENT ALL...
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 216                                                (X)
# 217                                                (X)
# 218                                                (X)
# 219                                                (X)
# 220                                                (X)
#
#                                         S0802_C05_099E  \
# 0    Estimate!!Worked from home!!PERCENT ALLOCATED!...
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 216                                                (X)
# 217                                                (X)
# 218                                                (X)
# 219                                                (X)
# 220                                                (X)
#
#                                         S0802_C05_099M  \
# 0    Margin of Error!!Worked from home!!PERCENT ALL...
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 216                                                (X)
# 217                                                (X)
# 218                                                (X)
# 219                                                (X)
# 220                                                (X)
#
#                                         S0802_C05_100E  \
# 0    Estimate!!Worked from home!!PERCENT ALLOCATED!...
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 216                                                (X)
# 217                                                (X)
# 218                                                (X)
# 219                                                (X)
# 220                                                (X)
#
#                                         S0802_C05_100M  \
# 0    Margin of Error!!Worked from home!!PERCENT ALL...
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 216                                                (X)
# 217                                                (X)
# 218                                                (X)
# 219                                                (X)
# 220                                                (X)
#
#                                         S0802_C05_101E  \
# 0    Estimate!!Worked from home!!PERCENT ALLOCATED!...
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 216                                                (X)
# 217                                                (X)
# 218                                                (X)
# 219                                                (X)
# 220                                                (X)
#
#                                         S0802_C05_101M
# 0    Margin of Error!!Worked from home!!PERCENT ALL...
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 216                                                (X)
# 217                                                (X)
# 218                                                (X)
# 219                                                (X)
# 220                                                (X)
#
# [221 rows x 1012 columns]

# %%
merged_2 = collin.merge(
    df,
    left_on="GEOIDFQ",
    right_on="GEO_ID",
    how="left"
)

merged_2["S0802_C01_094E"] = pd.to_numeric(
    merged_2["S0802_C01_094E"],
    errors="coerce"
)

# %%
fig, ax = plt.subplots(figsize=(10, 10))

merged_2.plot(
    column="S0802_C01_094E",
    cmap="viridis_r",
    legend=True,
    ax=ax
)

plt.title("Percentage of Workers with No Vehicles Available by Census Tract in Collin County")
plt.axis("off")
plt.show()

# %% [markdown]
# # 3. SNAP Map

# %%
df = pd.read_csv('collin_county_snap_data.csv')
df
# Out:
#                    GEO_ID                                       NAME  \
# 0               Geography                       Geographic Area Name
# 1    1400000US48085030101  Census Tract 301.01; Collin County; Texas
# 2    1400000US48085030102  Census Tract 301.02; Collin County; Texas
# 3    1400000US48085030201  Census Tract 302.01; Collin County; Texas
# 4    1400000US48085030202  Census Tract 302.02; Collin County; Texas
# ..                    ...                                        ...
# 216  1400000US48085032015  Census Tract 320.15; Collin County; Texas
# 217  1400000US48085032016  Census Tract 320.16; Collin County; Texas
# 218  1400000US48085032017  Census Tract 320.17; Collin County; Texas
# 219  1400000US48085032018  Census Tract 320.18; Collin County; Texas
# 220  1400000US48085032019  Census Tract 320.19; Collin County; Texas
#
#                   S2201_C01_001E                      S2201_C01_001M  \
# 0    Estimate!!Total!!Households  Margin of Error!!Total!!Households
# 1                           1012                                 117
# 2                           1323                                 151
# 3                           2666                                 263
# 4                           3468                                 254
# ..                           ...                                 ...
# 216                          863                                 118
# 217                          760                                  81
# 218                         2281                                 316
# 219                         1485                                 151
# 220                          928                                 134
#
#                                         S2201_C01_002E  \
# 0    Estimate!!Total!!Households!!With one or more ...
# 1                                                  405
# 2                                                  584
# 3                                                  987
# 4                                                 1276
# ..                                                 ...
# 216                                                432
# 217                                                245
# 218                                                571
# 219                                                699
# 220                                                409
#
#                                         S2201_C01_002M  \
# 0    Margin of Error!!Total!!Households!!With one o...
# 1                                                   97
# 2                                                  128
# 3                                                  243
# 4                                                  216
# ..                                                 ...
# 216                                                 81
# 217                                                113
# 218                                                148
# 219                                                150
# 220                                                114
#
#                                         S2201_C01_003E  \
# 0    Estimate!!Total!!Households!!No people in the ...
# 1                                                  607
# 2                                                  739
# 3                                                 1679
# 4                                                 2192
# ..                                                 ...
# 216                                                431
# 217                                                515
# 218                                               1710
# 219                                                786
# 220                                                519
#
#                                         S2201_C01_003M  \
# 0    Margin of Error!!Total!!Households!!No people ...
# 1                                                   79
# 2                                                  153
# 3                                                  302
# 4                                                  264
# ..                                                 ...
# 216                                                112
# 217                                                 77
# 218                                                330
# 219                                                188
# 220                                                125
#
#                                         S2201_C01_004E  \
# 0    Estimate!!Total!!Households!!Married-couple fa...
# 1                                                  670
# 2                                                  761
# 3                                                 2017
# 4                                                 2233
# ..                                                 ...
# 216                                                314
# 217                                                579
# 218                                               1214
# 219                                                763
# 220                                                772
#
#                                         S2201_C01_004M  ...  \
# 0    Margin of Error!!Total!!Households!!Married-co...  ...
# 1                                                   94  ...
# 2                                                  144  ...
# 3                                                  293  ...
# 4                                                  257  ...
# ..                                                 ...  ...
# 216                                                 85  ...
# 217                                                 75  ...
# 218                                                330  ...
# 219                                                157  ...
# 220                                                141  ...
#
#                                         S2201_C06_034E  \
# 0    Estimate!!Percent households not receiving foo...
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 216                                                (X)
# 217                                                (X)
# 218                                                (X)
# 219                                                (X)
# 220                                                (X)
#
#                                         S2201_C06_034M  \
# 0    Margin of Error!!Percent households not receiv...
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 216                                                (X)
# 217                                                (X)
# 218                                                (X)
# 219                                                (X)
# 220                                                (X)
#
#                                         S2201_C06_035E  \
# 0    Estimate!!Percent households not receiving foo...
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 216                                                (X)
# 217                                                (X)
# 218                                                (X)
# 219                                                (X)
# 220                                                (X)
#
#                                         S2201_C06_035M  \
# 0    Margin of Error!!Percent households not receiv...
# 1                                                  (X)
# 2                                                  (X)
# 3                                                  (X)
# 4                                                  (X)
# ..                                                 ...
# 216                                                (X)
# 217                                                (X)
# 218                                                (X)
# 219                                                (X)
# 220                                                (X)
#
#                                         S2201_C06_036E  \
# 0    Estimate!!Percent households not receiving foo...
# 1                                                 11.9
# 2                                                 11.9
# 3                                                  6.3
# 4                                                 12.9
# ..                                                 ...
# 216                                               18.1
# 217                                               12.6
# 218                                                  8
# 219                                               11.7
# 220                                                8.9
#
#                                         S2201_C06_036M  \
# 0    Margin of Error!!Percent households not receiv...
# 1                                                  6.1
# 2                                                  8.1
# 3                                                    4
# 4                                                  4.5
# ..                                                 ...
# 216                                                9.6
# 217                                                9.1
# 218                                                4.3
# 219                                                5.2
# 220                                                5.1
#
#                                         S2201_C06_037E  \
# 0    Estimate!!Percent households not receiving foo...
# 1                                                   25
# 2                                                 22.9
# 3                                                 28.7
# 4                                                 29.4
# ..                                                 ...
# 216                                               34.4
# 217                                               18.2
# 218                                               34.3
# 219                                               29.9
# 220                                                 26
#
#                                         S2201_C06_037M  \
# 0    Margin of Error!!Percent households not receiv...
# 1                                                 10.5
# 2                                                  9.1
# 3                                                  8.9
# 4                                                  6.8
# ..                                                 ...
# 216                                               12.4
# 217                                                8.2
# 218                                               14.4
# 219                                                9.4
# 220                                               10.9
#
#                                         S2201_C06_038E  \
# 0    Estimate!!Percent households not receiving foo...
# 1                                                   63
# 2                                                 65.2
# 3                                                 64.9
# 4                                                 57.8
# ..                                                 ...
# 216                                               47.5
# 217                                               69.2
# 218                                               57.7
# 219                                               58.4
# 220                                               65.1
#
#                                         S2201_C06_038M
# 0    Margin of Error!!Percent households not receiv...
# 1                                                 10.8
# 2                                                 10.8
# 3                                                  9.3
# 4                                                  6.8
# ..                                                 ...
# 216                                               11.8
# 217                                                8.8
# 218                                               15.4
# 219                                               11.2
# 220                                               12.1
#
# [221 rows x 458 columns]

# %%
merged_3 = collin.merge(
    df,
    left_on="GEOIDFQ",
    right_on="GEO_ID",
    how="left"
)

# %%
merged_3["S2201_C04_001E"] = pd.to_numeric(
    merged_3["S2201_C04_001E"],
    errors="coerce"
)

# %%
fig, ax = plt.subplots(figsize=(10, 10))

merged_3.plot(
    column="S2201_C04_001E",
    cmap="viridis_r",
    legend=True,
    ax=ax
)

plt.title("Percentage of SNAP Households per Census Tract in Travis County")
plt.axis("off")
plt.show()
