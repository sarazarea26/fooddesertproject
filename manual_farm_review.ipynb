# %%
# Bexar County
bexar_urban_farms = ["Garcia Streets Urban Farm","Green Bexar Farm", "pristine produce", "Raising the Barn", "J Heart Farm", "Pan's Microgreens", 
               "Viva Microgreens", "VIVA Microgreens", "MicroDaddy Microgreens", "Osiris Microgreens", "Armadillo Gardens", "Heritage Tomatoes of San Antonio",
              
              ]

""" 
-Garcia Streets Urban Farm: 4.1 Acres, sells produce, "Our farmers market offer a direct connection to fresh and affordable produce"
-Green Bexar Farm: 1 acre, CSA registration options  
-pristine produce: acreage unconfirmed but looks small based on google maps, sells produce based on instagram
-Raising the Barn: sells microgreens
-J Heart Farm: https://organic.nears.me/listings/united-states/texas/san-antonio-1/j-heart-farm-in-san-antonio-farm-guide/
- * Helotes Creek Farms: yes based off of reviews i found but there is no website so could be incorrect also addresses are different but both in san antonio https://trustburn.com/about/helotescreekfarms-com
- 
"""


not_farms = ["Bexar County AgriLife Urban Farm", "San Antonio Farmer's Market Association", "Make Ready Market", "Chicho Boys Fruit Market",
"Elsewhere Garden Bar & Kitchen", "San Antonio Botanical Garden",  "Market Plaza Center", "Fanick's Garden Center",  "Yanaguana Garden at Hemisfair", 
"Evergreen Garden Center","Growing Tx Greens Emporium", "Rainbow Gardens", "LocalSprout Food Hub", "Rainbow Gardens", "Lone Star Growers, LLC", "BV Hydroseeding & Hydromulching",
 "Greenhouses Etc", "E D Huntington Orchids and Tropicals", "CIELO VISTA FARM", "Pollinatives", "The Garden Center", "Palm Buddha", "Ambius", "Owl Creek Farm", "Calvary Farms", 
 "Hidden Tank Hollow", "Signature Springs Farm", "Behind the Oaks Farm", "Stoney Farms", "Farm Connection of North San Antonio, LLC", "San Antonio Flower Co",  "Cultivate | Blooms & Joyful Living",
 " Dirty Knuckle Farms", "Flowerama San Antonio", "The Tuscan Rose",  "Stablewood Farms Park", "Bexar County Agricultural Ext", "Trader's Town Country Market", "Medicinal Garden",
 "Jefferson Community Garden", "Porter Poultry & Egg Co", "Oak Farms Dairy San Antonio", "Nature Blessed Honey", "Farm Connection - Mainland Dr.", "Rogers & Sons Produce Inc.", 
 "Ryan's Happy Hens", "Shady Falls Farm", "The Little Victory Community Garden & Compost Site", "International Refugee Community Garden"
            ]

"""
- Bexar County AgriLife Urban Farm: no urban consulting agency, https://dunaway.com/project/bexar-county-greenies-urban-farm/
-San Antonio Farmer's Market Association: its a farmers market
-Fanick's Garden Center: sells pecans and is a plant nursery 
-Evergreen Garden Center: plant store 
-Yanaguana Garden at Hemisfair: park 
-Growing Tx Greens Emporium: plant nursery 
-Rainbow Gardens: nursery
-LocalSprout Food Hub: hosts food vendors
-Lone Star Growers, LLC: plant nursery 
-BV Hydroseeding & Hydromulching: landscaping 
-Greenhouses Etc: greenhouse materials 
-E D Huntington Orchids and Tropicals: flowers 
-CIELO VISTA FARM: 39 acres 
-Pollinatives: plant nursery 
-Palm Buddha: plant nursery 
- Soli Organic 3315 Global Way: only sells herbs 
- Ambius: landscaping
-Owl Creek Farm: no produce
-Calvary Farms: animals only 
-hidden tank hollow: 7 acres
-Signature Springs Farm: only sells meat
-Behind the Oaks Farm: only sells meat
-Stoney Farms: no info found, google photos makes it seem like a restrauant 
- Maple Grove Farms: no info found, google photos provides no additional information
- Farm Connection of North San Antonio, LLC: farmer market host
-Dirty Knuckle Farms: not a farm 
-Trader's Town Country Market: market place
-Medicinal Garden: does not sell produce 
-Alamo Farms: groery store
- Helotes Creek Farms: not a ton of info but seems to only sell meat
- Oak Farms Dairy San Antonio: dairy only
"""
# Out:
# "\n- Bexar County AgriLife Urban Farm: no urban consulting agency, https://dunaway.com/project/bexar-county-greenies-urban-farm/\n-San Antonio Farmer's Market Association: its a farmers market\n-Fanick's Garden Center: sells pecans and is a plant nursery \n-Evergreen Garden Center: plant store \n-Yanaguana Garden at Hemisfair: park \n-Growing Tx Greens Emporium: plant nursery \n-Rainbow Gardens: nursery\n-LocalSprout Food Hub: hosts food vendors\n-Lone Star Growers, LLC: plant nursery \n-BV Hydroseeding & Hydromulching: landscaping \n-Greenhouses Etc: greenhouse materials \n-E D Huntington Orchids and Tropicals: flowers \n-CIELO VISTA FARM: 39 acres \n-Pollinatives: plant nursery \n-Palm Buddha: plant nursery \n- Soli Organic 3315 Global Way: only sells herbs \n- Ambius: landscaping\n-Owl Creek Farm: no produce\n-Calvary Farms: animals only \n-hidden tank hollow: 7 acres\n-Signature Springs Farm: only sells meat\n-Behind the Oaks Farm: only sells meat\n-Stoney Farms: no info found, g
# ...

# %%
# Tarrant County
tarrant_urban_farms = ["Opal's Farm", "Tabor Farms", "The Barn (formerly Elizabeth Anna's Old World Garden)",
"Mushroom Street Farms", "Green Phoenix Farms", "Stone's Throw Farm Co","Texas Fungus", "Mushroom Street Farms", "Giselle Borges",
]

"""
- Tabor Farms: 2.5 acres : https://fortworthreport.org/2023/04/26/green-thumbs-meet-red-tape-after-years-of-delays-a-nonprofit-wants-to-make-it-easier-to-farm-in-fort-worth/

"""

discard = ["Viva City", "West Fork Garden Market",
"Common Ground NRH Community Garden",
"Fort Worth Community Market",
"Tarrant County Master Gardeners Community Demonstration Garden",
"ZaGardens Market", "Mansfield Farm and Cottage Market", "Fort Worth Public Market",
"The Flower Market On 7th",
"Farmer's Market Precut",
"The Harden at Public Marke",
"Nativo Gardens",
"Abundant Harvest Hydroponics & Organics",
"Caged Tomato", "Timberview Farmstead",
"Grow Plant Shop",
"Moreno Plant Farms",
"Texas Greenhouse Co",
"Green's Produce and Plants",
"Claytonhill Greenhouse Co LLC",
"Claytonhill Greenhouse",
"Fifth Avenue Greenhouses Inc.",
"Weston Gardens In Bloom, Inc", "Village Farm", "Leno's Plant Farm",
"Archie's Gardenland", "Fort Worth Farm Company","Tropical Greenery",
"Petting Barn at Fort Worth Zoo", "Nash Farm", "Howell Family Farms",
"The Dunham Farm / Dunham Farm Wildlife Park / Petting Zoo", "Hope Farm, Inc.",
"Conundrum Farms",
"Powells Family Farm", "DFW Organic Growing",
"Vital Greens", "Rosemont Farms", "Camellia Farm Flora",
"Sanderson Creek Bonsai",
"Urban Plantology",
"Gordon Boswell Flowers", "Backyard Vegetable Garden", "Fort Worth Petting Zoo", "Egg Farm Road", "Hive Riot Honey Company"
"Heavenly Honey", "Midnight Mushroom Co."
"Maggie's Farm",
"Smallside Farm",
"Texas Agrilife Ext Tarrant Co", 
"Quail Haven Urban Farm", "Nine Mile Farm - Fresh Duck Eggs", "Broken Paddle Farm","DFW Organic Growing",
"C&B Fleece Fur and Feathers",
    
           
           
    
]

"""
Fort Worth Farm Company: only sells flowers, donates fresh produce 
Nash Farm: 5.2 acres 
Rosemont Farms: no information 
Backyard Vegetable Garden: donates to soup kitchen and church organization 

"""

# %%
import pandas as pd

county ="bexar"

df = pd.read_csv(f"urbanFarmData/pre_llm_datasets/filtered_{county}_farms.csv")

urban_farms = ["Garcia Street Urban Farm", "Green Bexar Farm", "pristine produce", "Raising the Barn",
               "J Heart Farm", "Pan's Microgreens", "Viva Microgreens", "VIVA Microgreens",
               "MicroDaddy Microgreens", "Osiris Microgreens", "Armadillo Gardens",
               "Heritage Tomatoes of San Antonio"]

# Normalize for case-insensitive, whitespace-safe matching
urban_farms_clean = set(name.strip().lower() for name in urban_farms)

# Change "name" below to whatever the actual column with farm names is called
name_col = "name"

filtered_df = df[df[name_col].str.strip().str.lower().isin(urban_farms_clean)]

filtered_df.to_csv(f"final_urban_farms_{county}.csv", index=False)
filtered_df
# Out:
#                                 name  \
# 0           Garcia Street Urban Farm
# 7                   Green Bexar Farm
# 15                  Pristine Produce
# 19                  Raising the Barn
# 33                      J Heart Farm
# 36                 Pan's Microgreens
# 37                  Viva Microgreens
# 38                  VIVA Microgreens
# 40            MicroDaddy Microgreens
# 41                Osiris Microgreens
# 59                 Armadillo Gardens
# 60  Heritage Tomatoes of San Antonio
#
#                                               address        lat        lon  \
# 0           218 Garcia St, San Antonio, TX 78203, USA  29.417766 -98.444261
# 7             14997 FM 1346, St Hedwig, TX 78152, USA  29.378845 -98.187918
# 15  723 SE Loop 410 Acc Rd, San Antonio, TX 78220,...  29.416297 -98.390431
# 19      6339 Pickering Dr, San Antonio, TX 78238, USA  29.489342 -98.614008
# 33           19320 FM1937, San Antonio, TX 78221, USA  29.232250 -98.456340
# ...
