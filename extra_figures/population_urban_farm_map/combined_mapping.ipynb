# %%
import pandas as pd
import geopandas as gpd
#from shapely.geometry import Point
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from shapely.ops import unary_union
from matplotlib.lines import Line2D
from shapely.geometry import MultiPolygon

# %%
county = "harris"

farms_df = pd.read_csv(f"final_urban_farms_harris.csv")

farms_gdf = gpd.GeoDataFrame(
    farms_df,
    geometry=gpd.points_from_xy(farms_df["lon"], farms_df["lat"]),
    crs="EPSG:4326"  # standard lat/lon
)

# %%
final = pd.read_csv("harris_bivariate_data.csv")
county_tracts = gpd.read_file("tl_2025_48_tract.shp")
county_tracts = county_tracts[county_tracts['COUNTYFP'] == '201'].copy()  # FIPS
county_tracts['TractFIPS'] = county_tracts['GEOID'].astype('int64')

choropleth_gdf = county_tracts.merge(final, on='TractFIPS', how='inner')

# %%
grocery_df = pd.read_csv(f"cleaned_harris_snap_data.csv")

grocery_gdf = gpd.GeoDataFrame(
    grocery_df,
    geometry=gpd.points_from_xy(grocery_df["Longitude"], grocery_df["Latitude"]),
    crs="EPSG:4326"
)

grocery_gdf = grocery_gdf.to_crs(choropleth_gdf.crs)

# %%
print(county_tracts.shape)
print(choropleth_gdf.shape)  # or whatever you named it
# Out:
# (1115, 15)
# (1110, 19)

# %%
print(choropleth_gdf.geometry.head())
# Out:
# 0    POLYGON ((-95.14357 29.64973, -95.13828 29.649...
# 1    POLYGON ((-95.47652 29.72445, -95.4765 29.7247...
# 2    POLYGON ((-95.5282 29.67272, -95.52642 29.6721...
# 3    POLYGON ((-95.58373 29.65943, -95.58314 29.659...
# 4    POLYGON ((-95.38327 29.66813, -95.38314 29.668...
# Name: geometry, dtype: geometry

# %%
print(choropleth_gdf.crs)
farms_gdf = farms_gdf.to_crs(choropleth_gdf.crs)
# Out:
# EPSG:4269

# %%
# bivariate classification:
def tercile(x):
    if x <= 33.33: return 1
    elif x <= 66.67: return 2
    else: return 3

choropleth_gdf["x_class"] = choropleth_gdf["income_mobility_pct"].apply(tercile)
choropleth_gdf["y_class"] = choropleth_gdf["health_pct"].apply(tercile)
choropleth_gdf["bivar_class"] = choropleth_gdf["x_class"].astype(str) + "-" + choropleth_gdf["y_class"].astype(str)

# # original color scheme
# color_map = {
#     "1-1": "#e8e8e8", "2-1": "#b5c0da", "3-1": "#6c83b5",
#     "1-2": "#dfb0d6", "2-2": "#a5add3", "3-2": "#5a77ad",
#     "1-3": "#be64ac", "2-3": "#8c62aa", "3-3": "#3b4994",
# }

# color_map = {
#     "1-1": "#e8e8e8", "2-1": "#c8b7a6", "3-1": "#b8860b",
#     "1-2": "#aed1e0", "2-2": "#a89a8c", "3-2": "#9c7a2e",
#     "1-3": "#5698c4", "2-3": "#6d7a8c", "3-3": "#4d3319",
# }

color_map = {
    "1-1": "#EFF2F1", "2-1": "#F1D599", "3-1": "#F4B942",
    "1-2": "#97A5CF", "2-2": "#AFA396", "3-2": "#C7A15D",
    "1-3": "#4059AD", "2-3": "#6D7292", "3-3": "#9A8978",
}

choropleth_gdf["fill_color"] = choropleth_gdf["bivar_class"].map(color_map)

# grocery store categorization: 
store_color_map = {
    "Supermarket": "#000000",         # black
    "Grocery Store": "#000000",       # dark grey
    "Super Store": "#000000",         # mid grey
    "Farmers and Markets": "#d9d9d9", # light grey
    "Convenience Store": "#000000",
    "Specialty Store": "#000000",
    "Other": "#000000",               # white
}
grocery_gdf["store_color"] = grocery_gdf["Store_Type"].map(store_color_map)

# buffers around grocery store:
# grocery_projected = grocery_gdf.to_crs("EPSG:3083")
# one_mile_m = 1609.34
# grocery_projected["buffer"] = grocery_projected.geometry.buffer(one_mile_m)
# buffers_gdf = gpd.GeoDataFrame(grocery_projected, geometry="buffer", crs="EPSG:3083").to_crs(choropleth_gdf.crs)

# additional filter to remove points outside the county:
boundary = unary_union(choropleth_gdf.geometry.buffer(0))

if isinstance(boundary, MultiPolygon):
    boundary = max(boundary.geoms, key=lambda g: g.area)

grocery_gdf = grocery_gdf[grocery_gdf.within(boundary)].copy()
farms_gdf = farms_gdf[farms_gdf.within(boundary)].copy()

boundary_proj = gpd.GeoSeries([boundary], crs=choropleth_gdf.crs).to_crs("EPSG:3083").iloc[0]
# grocery_projected["buffer"] = grocery_projected["buffer"].intersection(boundary_proj)
# buffers_gdf = gpd.GeoDataFrame(grocery_projected, geometry="buffer", crs="EPSG:3083").to_crs(choropleth_gdf.crs)

# building the overall figure:
fig, ax = plt.subplots(figsize=(10, 10))

# Layer 1: bivariate choropleth
choropleth_gdf.plot(color=choropleth_gdf["fill_color"], edgecolor="white", linewidth=0.3, ax=ax, zorder=1)


# Layer 2: grocery stores (color-coded by store type)
grocery_gdf.plot(ax=ax, color=grocery_gdf["store_color"], marker="o",
                  markersize=25, edgecolor="white", linewidth=0.4, zorder=2)

# Layer 3: urban farms 
# White triangle with black outline
farms_gdf.plot(ax=ax, color="#D2691E", marker="^", markersize=100,
               edgecolor="#D2691E", linewidth=1.0, zorder=4)

ax.set_axis_off()
ax.set_title(f"Food Deserts, Urban Farms, Income & Mobility, and Health Risk\n{county.title()} County Census Tracts")
ax.set_position([0.05, 0.15, 0.9, 0.8])

# Bivariate legend square (unchanged)
legend_ax = fig.add_axes([0.08, 0.02, 0.15, 0.15])

# # original grid color 
# grid_colors = [
#     ["#e8e8e8", "#b5c0da", "#6c83b5"],
#     ["#dfb0d6", "#a5add3", "#5a77ad"],
#     ["#be64ac", "#8c62aa", "#3b4994"],
# ]

# colorblind friendly grid color 

# grid_colors = [
#     ["#e8e8e8", "#c8b7a6", "#b8860b"],
#     ["#aed1e0", "#a89a8c", "#9c7a2e"],
#     ["#5698c4", "#6d7a8c", "#4d3319"],
# ]

grid_colors = [
    ["#EFF2F1", "#F1D599", "#F4B942"],
    ["#97A5CF", "#AFA396", "#C7A15D"],
    ["#4059AD", "#6D7292", "#9A8978"],
]

for row in range(3):
    for col in range(3):
        legend_ax.add_patch(Rectangle((col, row), 1, 1, facecolor=grid_colors[row][col], edgecolor="white", linewidth=0.5))
legend_ax.set_xlim(0, 3)
legend_ax.set_ylim(0, 3)
legend_ax.set_xticks([])
legend_ax.set_yticks([])
legend_ax.set_xlabel("income & mobility ->", fontsize=8)
legend_ax.set_ylabel("health risks ->", fontsize=8)
legend_ax.set_title("Legend", fontsize=9)

# Point legend 
store_legend_elements = [
    Line2D([0], [0], marker='o', color='w', markerfacecolor="#000000", markersize=8, label="Grocery Stores"),
    Line2D([0], [0], marker='o', color='w', markerfacecolor="#d9d9d9", markersize=8, label="Farmers Market"),
]
farm_legend_element = [Line2D([0], [0], marker='^', color='w', markerfacecolor='#D2691E', markeredgecolor='#D2691E', markersize=10, label='Urban Farms')]

ax.legend(
    handles=store_legend_elements + farm_legend_element,
    loc='upper left',
    bbox_to_anchor=(1.02, 1),  # x=1.02 pushes it just outside the right edge of the axes, y=1 aligns to top
    frameon=False,
    fontsize=8
)

plt.savefig(f"{county}_integrated_map.png", dpi=200, bbox_inches="tight")
plt.show()

# %%
print(grocery_gdf["store_color"].isna().sum())
print(grocery_gdf[grocery_gdf["store_color"].isna()]["Store_Type"].unique())
# Out:
# 0
# <StringArray>
# []
# Length: 0, dtype: str

# %%
print(final.columns.tolist())
# Out:
# ['TractFIPS', 'final_income_mobility_composite', 'final_health_composite', 'income_mobility_pct', 'health_pct']

# %%
#matplotlib installation 
import sys
print(sys.executable)
# Out:
# c:\Users\saraz\anaconda3\envs\pandas\python.exe

# %%
#harris population 
population = pd.read_csv("harris_tract_population.csv")

# %%
#what columns are 
print(population.columns.tolist())
# Out:
# ['GEO_ID', 'NAME', 'B01003_001E', 'B01003_001M']

# %%
#first few rows
population.head()
# Out:
#                  GEO_ID                                        NAME  \
# 0             Geography                        Geographic Area Name
# 1  1400000US48201100001  Census Tract 1000.01; Harris County; Texas
# 2  1400000US48201210400     Census Tract 2104; Harris County; Texas
# 3  1400000US48201210500     Census Tract 2105; Harris County; Texas
# 4  1400000US48201210600     Census Tract 2106; Harris County; Texas
#
#        B01003_001E             B01003_001M
# 0  Estimate!!Total  Margin of Error!!Total
# 1             5869                     917
# 2             3628                     585
# 3             4767                     585
# 4             5415                    1589

# %%
#skip 1st row 
population = pd.read_csv("harris_tract_population.csv", skiprows=[1])

# %%
population.head()
# Out:
#                  GEO_ID                                        NAME  \
# 0  1400000US48201100001  Census Tract 1000.01; Harris County; Texas
# 1  1400000US48201210400     Census Tract 2104; Harris County; Texas
# 2  1400000US48201210500     Census Tract 2105; Harris County; Texas
# 3  1400000US48201210600     Census Tract 2106; Harris County; Texas
# 4  1400000US48201210700     Census Tract 2107; Harris County; Texas
#
#    B01003_001E  B01003_001M
# 0         5869          917
# 1         3628          585
# 2         4767          585
# 3         5415         1589
# 4         2208          410

# %%
#calculate population density

#matching tract ID
population["TractFIPS"] = (
    population["GEO_ID"]
    .str.replace("1400000US", "", regex=False)
    .astype("int64")
)

#keep only columns you need 
population = population[["TractFIPS", "B01003_001E"]].copy()

#population numeric
population["B01003_001E"] = pd.to_numeric(
    population["B01003_001E"],
    errors="coerce"
)

#merge into dataframe
choropleth_gdf = choropleth_gdf.merge(
    population,
    on="TractFIPS",
    how="left"
)

#calculate population density 
# ALAND is land area in square meters
choropleth_gdf["population_density"] = (
    choropleth_gdf["B01003_001E"] /
    (choropleth_gdf["ALAND"] / 2_589_988.110336)
)

#verify it worked
print(
    choropleth_gdf[
        ["TractFIPS", "B01003_001E", "population_density"]
    ].head()
)

print(choropleth_gdf["population_density"].describe())
# Out:
#      TractFIPS  B01003_001E  population_density
# 0  48201342001         6399         3279.779766
# 1  48201421101         2746         5742.262032
# 2  48201423301         4664         7303.169064
# 3  48201453401         3639         9782.873148
# 4  48201331100         4129         3309.501256
# count     1110.000000
# mean      6395.841251
# std       5497.132273
# min         80.568283
# 25%       3217.969461
# 50%       5159.582204
# 75%       7427.815798
# max      58804.592216
# Name: population_density, dtype: float64

# %%
# make map 


# Put farm points in the same CRS as the census tracts
farms_gdf = farms_gdf.to_crs(choropleth_gdf.crs)

# Keep only farms inside Harris County tracts
boundary = choropleth_gdf.geometry.union_all()

farms_gdf = farms_gdf[
    farms_gdf.geometry.intersects(boundary)
].copy()

print("Urban farms displayed:", len(farms_gdf))
# Out:
# Urban farms displayed: 20

# %%
#plot 

fig, ax = plt.subplots(figsize=(11, 10))

# Population density choropleth
choropleth_gdf.plot(
    column="population_density",
    cmap="YlOrRd",
    edgecolor="white",
    linewidth=0.25,
    legend=True,
    legend_kwds={
        "label": "Population density (people per square mile)",
        "shrink": 0.65
    },
    ax=ax,
    zorder=1
)

# Urban farms
farms_gdf.plot(
    ax=ax,
    marker="^",
    color="#D2691E",
    edgecolor="black",
    linewidth=0.8,
    markersize=100,
    zorder=3
)

farm_legend = Line2D(
    [0],
    [0],
    marker="^",
    linestyle="None",
    markerfacecolor="#D2691E",
    markeredgecolor="black",
    markersize=10,
    label="Urban Farm"
)

ax.legend(
    handles=[farm_legend],
    loc="upper right",
    frameon=True
)

ax.set_title(
    "Urban Farms and Population Density\nHarris County Census Tracts",
    fontsize=14
)

ax.set_axis_off()

plt.tight_layout()

plt.savefig(
    "harris_urban_farms_population_density.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
#replace with quantiles to show more gradient 

choropleth_gdf.plot(
    column="population_density",
    scheme="Quantiles",
    k=5,
    cmap="YlOrRd",
    edgecolor="white",
    linewidth=0.25,
    legend=True,
    legend_kwds={
        "title": "Population density\n(people per sq. mile)",
        "loc": "lower right"
    },
    ax=ax,
    zorder=1
)
# Out:
# <Axes: title={'center': 'Urban Farms and Population Density\nHarris County Census Tracts'}>

# %%
#install package 

import sys
# !{sys.executable} -m pip install mapclassify
# Out:
# Requirement already satisfied: mapclassify in c:\users\saraz\anaconda3\envs\pandas\lib\site-packages (2.10.0)
# Requirement already satisfied: networkx>=3.2 in c:\users\saraz\anaconda3\envs\pandas\lib\site-packages (from mapclassify) (3.6.1)
# Requirement already satisfied: numpy>=1.26 in c:\users\saraz\anaconda3\envs\pandas\lib\site-packages (from mapclassify) (2.5.0)
# Requirement already satisfied: pandas>=2.1 in c:\users\saraz\anaconda3\envs\pandas\lib\site-packages (from mapclassify) (3.0.3)
# Requirement already satisfied: scikit-learn>=1.4 in c:\users\saraz\anaconda3\envs\pandas\lib\site-packages (from mapclassify) (1.9.0)
# Requirement already satisfied: scipy>=1.12 in c:\users\saraz\anaconda3\envs\pandas\lib\site-packages (from mapclassify) (1.18.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\saraz\anaconda3\envs\pandas\lib\site-packages (from pandas>=2.1->mapclassify) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\saraz\anaconda3\envs\pandas\lib\site-packages (from pandas>=2.1->mapclassify) (2026.2)
# Requirement already satisfied: joblib>=1.4.0 in c:\users\saraz\anaconda3\envs\pandas\lib\site-packages (from scikit-learn>=1.4->mapclassify) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in c:\users\saraz\anaconda3\envs\pandas\lib\site-packages (from scikit-learn>=1.4->mapclassify) (2.23.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\users\saraz\anaconda3\envs\pandas\lib\site-packages (from scikit-learn>=1.4->mapclassify) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\saraz\anaconda3\envs\pandas\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.1->mapclassify) (1.17.0)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\saraz\anaconda3\envs\pandas\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\saraz\anaconda3\envs\pandas\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (c:\Users\saraz\anaconda3\envs\pandas\Lib\site-packages)

# %%
plt.show()

# %%
fig, ax = plt.subplots(figsize=(11, 10))

choropleth_gdf.plot(
    column="population_density",
    cmap="YlOrRd",
    ax=ax
)

farms_gdf.plot(
    ax=ax,
    marker="^",
    color="#D2691E",
    markersize=60
)

plt.show()
