# %%
import geopandas as gpd
import numpy as np

# Load GeoPackage
gdf = gpd.read_file("dallas_modeling_final.gpkg")

# Replace with the variable you want to test
variable = "your_variable"

# Keep only valid, nonmissing observations
gdf = gdf[gdf.geometry.notna() & gdf[variable].notna()].copy()
gdf = gdf.reset_index(drop=True)

# Convert variable to numeric
gdf[variable] = gdf[variable].astype(float)
# Out:
# ---------------------------------------------------------------------------
# DataSourceError                           Traceback (most recent call last)
# Cell In[2], line 5
#       2 import numpy as np
#       4 # Load GeoPackage
# ----> 5 gdf = gpd.read_file("dallas_modeling_final.gpkg")
#       7 # Replace with the variable you want to test
#       8 variable = "your_variable"
#
# File c:\Users\saraz\anaconda3\envs\pandas\Lib\site-packages\geopandas\io\file.py:316, in _read_file(filename, bbox, mask, columns, rows, engine, **kwargs)
#     313             filename = response.read()
#     315 if engine == "pyogrio":
# --> 316     return _read_file_pyogrio(
#     317         filename, bbox=bbox, mask=mask, columns=columns, rows=rows, **kwargs
#     318     )
#     320 elif engine == "fiona":
#     321     if pd.api.types.is_file_like(filename):
#
# ...
