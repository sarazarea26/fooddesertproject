# %%
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point
import matplotlib.pyplot as plt
from shapely.geometry import Point
import pandas as pd
from plotnine import *
from geopandas import GeoDataFrame
import contextily as cx

# %matplotlib inline

# %%
# converting to points 
df = pd.read_csv("cleaned_tarrant_snap_data.csv")

# Create point geometries
geometry = gpd.points_from_xy(df["Longitude"], df["Latitude"])

geo_df = gpd.GeoDataFrame(
    df[["Store_Name", "Store_Street_Address", "City", "Zip_Code", "Store_Type", "Latitude", "Longitude"]], 
    geometry=geometry,
    crs="EPSG:4326"
)

geo_df.head()
# Out:
#                              Store_Name Store_Street_Address       City  \
# 0  Iyanu African Caribbean Marketplace     2154 N Collins St  Arlington
# 1     Sana Restaurant And Halal Grocery      5941 Watauga Rd    Watauga
# 2           Victory Tropical Market Inc        415 N Main St     Euless
# 3              Whole Foods Market 10098     801 E Lamar Blvd  Arlington
# 4                     Target Store 1765      8000 Denton Hwy    Watauga
#
#    Zip_Code     Store_Type   Latitude  Longitude                    geometry
# 0     76011  Grocery Store  32.768894 -97.098106  POINT (-97.09811 32.76889)
# 1     76148  Grocery Store  32.861015 -97.252441  POINT (-97.25244 32.86102)
# 2     76039  Grocery Store  32.842609 -97.082672  POINT (-97.08267 32.84261)
# 3     76011    Super Store  32.766853 -97.099075  POINT (-97.09908 32.76685)
# 4     76148    Super Store  32.889248 -97.256554  POINT (-97.25655 32.88925)

# %%
# dallas= gpd.read_file("tl_2025_48_tract.shp")
tarrant = gpd.read_file("../Census_Tract/tl_2025_48_tract.shp")

# %%
# filter for only dallas county
tarrant = tarrant[tarrant["COUNTYFP"] == "439"]

print(tarrant.shape)
tarrant.plot()
# Out:
# (449, 14)
# <Axes: >

# %%
print("tarrant CRS:", tarrant.crs)
print("geo_df CRS:", geo_df.crs)
# Out:
# tarrant CRS: EPSG:4269
# geo_df CRS: EPSG:4326

# %%
# convert my data to Web Mercator because it matches the mapping data we are using from contexitly
tarrant_wm = tarrant.to_crs(epsg=3857)
geo_df_wm = geo_df.to_crs(epsg=3857)

# %%
# convert to the right coordinate format
geo_df_projected = geo_df.to_crs(epsg=32614)
tarrant_projected = tarrant.to_crs(epsg=32614)

# create buffers
geo_df_buffer = geo_df_projected.copy()
geo_df_buffer["geometry"] = geo_df_projected.geometry.buffer(1609)

colors = {
    "Grocery Store": "green",
    "Supermarket": "blue",
    "Super Store": "purple",
    "Farmers and Markets": "orange",
    "Other": "red"
}

fig, ax = plt.subplots(figsize=(14, 12))

# project both graphs
tarrant_projected.plot(ax=ax, color="whitesmoke", edgecolor="lightgrey", linewidth=0.5)
geo_df_buffer.plot(ax=ax, color="lightblue", alpha=0.15, edgecolor="blue", linewidth=0.3)

for store_type, color in colors.items():
    subset = geo_df_projected[geo_df_projected["Store_Type"] == store_type]
    subset.plot(ax=ax, marker='o', color=color, markersize=8, alpha=0.7, label=store_type)

# legend 
ax.set_xlim(tarrant_projected.total_bounds[[0, 2]])
ax.set_ylim(tarrant_projected.total_bounds[[1, 3]])

ax.legend(title="Store Type", fontsize=10, title_fontsize=11, loc="lower right")
ax.axis("off")
ax.set_title("SNAP Grocery Stores in Tarrant County", fontsize=16, fontweight="bold", pad=5)
plt.tight_layout()
plt.show()

# %%
# adding OpenStreetMap
shp_path = "../OpenStreetMap/gis_osm_roads_free_1.shp"
roads = GeoDataFrame.from_file(shp_path, encoding='utf-8')
roads.head()
# Out:
#     osm_id  code         fclass                 name   ref oneway  maxspeed  \
# 0  4342988  5111       motorway  Sam Rayburn Tollway   SRT      F       112
# 1  4343083  5111       motorway  Sam Rayburn Tollway   SRT      F       112
# 2  4343084  5111       motorway  Sam Rayburn Tollway   SRT      F       112
# 3  4343087  5131  motorway_link                 None  None      F         0
# 4  4343088  5131  motorway_link                 None  None      F         0
#
#    layer bridge tunnel                                           geometry
# 0      0      F      F  LINESTRING (-97.00107 32.98973, -97.0021 32.99...
# 1      0      F      F  LINESTRING (-97.00623 32.99057, -97.00568 32.9...
# 2      1      T      F  LINESTRING (-96.99295 32.98645, -96.99329 32.9...
# 3      0      F      F  LINESTRING (-96.99882 32.98826, -96.9981 32.98...
# 4      0      F      F  LINESTRING (-96.99669 32.98806, -96.99731 32.9...

# %%
# testing 
ax = tarrant_wm.plot(figsize=(10, 10), alpha=0.5, edgecolor="k", facecolor="none")
cx.add_basemap(ax, source=cx.providers.CartoDB.Positron)

# %%
geo_df_buffer_wm = geo_df_wm.copy()

geo_df_buffer_wm["geometry"] = geo_df_wm.geometry.buffer(1609)
roads_wm = roads.clip(tarrant.total_bounds).to_crs(epsg=3857)

cx.add_basemap(ax, source=cx.providers.CartoDB.Positron, zorder=0)

colors = {
    "Grocery Store": "green",
    "Supermarket": "blue",
    "Super Store": "purple",
    "Farmers and Markets": "orange",
    "Other": "red"
}

fig, ax = plt.subplots(figsize=(14, 12))

roads_wm.plot(ax=ax, color="gray", linewidth=0.3, alpha=0.4)
geo_df_buffer_wm.plot(ax=ax, color="steelblue", alpha=0.15, edgecolor="blue", linewidth=0.3)

for store_type, color in colors.items():
    subset = geo_df_wm[geo_df_wm["Store_Type"] == store_type]
    subset.plot(ax=ax, marker='o', color=color, markersize=8, alpha=0.7, label=store_type)
    
ax.set_xlim(tarrant_wm.total_bounds[[0, 2]])
ax.set_ylim(tarrant_wm.total_bounds[[1, 3]])

ax.legend(title="Store Type", fontsize=10, title_fontsize=11, loc="lower right")
ax.axis("off")
ax.set_title("SNAP Grocery Stores in Tarrant County", fontsize=16, fontweight="bold", pad=5)
plt.tight_layout()

plt.savefig("Tarrant_snap_map.png", dpi=300, bbox_inches="tight")
plt.show()
