# %%
 """ 
bexar county filter out row 65, 66
dallas county filter out row 66
Harris county:
     keep: 
     - row 78 (Hope Farms Urban Agricultural Showcase and Training Center - Recipes for Success, Website: http://hopefarmshtx.org/
     drop: 
     - row 80
     - row 81
     - row 82
     - row 84
     - row 87

Tarrant county: filter out row 66 
Travis county: 
    drop:
    - row 78
    - row 81
    - row 83
    - row 84
    - row 85
    - row 87
     """
